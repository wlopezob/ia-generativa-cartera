# %% [markdown]
# # Querying a GitHub Codebase with Vertex AI RAG Engine
#
# sources: https://github.com/kweinmeister/notebooks/blob/master/rag_codebase.ipynb
#
# This notebook demonstrates how to use Vertex AI's Retrieval-Augmented Generation (RAG) capabilities to index the code files from a public GitHub repository and then ask questions about that codebase using a generative model.
#
# It uses Vertex AI RAG Engine, a component of the Vertex AI Platform.
# ## Setup
# ### Install Packages
#
# This cell installs the required Python libraries:
#
# - google-cloud-aiplatform: The Vertex AI SDK for interacting with Vertex AI services like RAG and Gemini models.
# - google-cloud-storage: The SDK for interacting with Google Cloud Storage (GCS).
# - gitpython: A library to interact with Git repositories (cloning).
# - google-genai: The Google Generative AI SDK (used here for simplified client interaction via genai.Client).
#
# It also restarts the Colab kernel, which is often necessary after installing new packages.

# %% [markdown]
# ## Import Libraries
#
# Imports the necessary Python modules used throughout the notebook.

# %%
import os
import uuid

import git
from google import genai
from google.cloud import storage
from google.genai.types import GenerateContentConfig, Retrieval, Tool, VertexRagStore
from IPython.display import display, HTML, Markdown
import vertexai
from vertexai import rag

# %% [markdown]
# ## Configuration
# ### Define Parameters
#
# Set the configuration variables required for the notebook. You must replace placeholder values (like [your-project-id], [your-bucket-name]) with your specific details.
#
# - GITHUB_URL: The URL of the public GitHub repository to index.
# - PROJECT_ID: Your Google Cloud Project ID.
# - LOCATION: The Google Cloud region where resources will be created (e.g., us-central1).
# - BUCKET_NAME: The name of the GCS bucket used for staging code files. Ensure this bucket exists in your project.
# - GCS_FOLDER_PATH: An optional prefix (folder path) within the bucket to organize the uploaded code files.
# - MAX_FILE_SIZE_MB: A limit to skip uploading very large files (0 means no limit).
# - EMBEDDING_MODEL: The Vertex AI text embedding model used to create vector representations of the code chunks.
# - MODEL_ID: The Vertex AI Gemini model used for answering questions.
# - RAG_CORPUS_DISPLAY_NAME, RAG_ENGINE_DISPLAY_NAME: Unique display names for the RAG resources being created.
# - SUPPORTED_EXTENSIONS: A list of file extensions and specific filenames to identify code, configuration, and documentation files for indexing.

# %%
GITHUB_URL = "https://github.com/google/adk-python"  #@param {"type":"string", "placeholder": "https://github.com/google/adk-python"}
PROJECT_ID = "masmovil-461118"  #@param {type:"string", placeholder: "[your-project-id]", isTemplate: true}
LOCATION = "us-central1"              #@param {type:"string"}
BUCKET_NAME = "rag-wlopezob"  #@param {type:"string", placeholder: "[your-bucket-name]", isTemplate: true}
GCS_FOLDER_PATH = "adk-python" #@param {type:"string"} - The folder path (prefix) within the bucket where code files will be stored.
MAX_FILE_SIZE_MB = 50 #@param {type:"number"} - Maximum individual file size in MB to upload. Set to 0 for no limit.
EMBEDDING_MODEL = "publishers/google/models/text-embedding-005"  # @param {type:"string", isTemplate: true}
MODEL_ID = "gemini-2.5-flash-preview-04-17"  # @param {type:"string", "placeholder": "gemini-2.5-flash-preview-04-17", isTemplate: true}

GCS_FOLDER_PATH = GCS_FOLDER_PATH.strip('/')
BUCKET_URI = f"gs://{BUCKET_NAME}"
GCS_UPLOAD_URI = f"{BUCKET_URI}/{GCS_FOLDER_PATH}" if GCS_FOLDER_PATH else BUCKET_URI
GCS_IMPORT_URI = f"{GCS_UPLOAD_URI}/"
LOCAL_REPO_PATH = "./cloned_repo"

# RAG Engine Configuration
RAG_CORPUS_DISPLAY_NAME = f"rag-corpus-code-{uuid.uuid4()}"
RAG_ENGINE_DISPLAY_NAME = f"rag-engine-code-{uuid.uuid4()}"

# Supported file extensions for ingestion (adjust as needed)
# Common code, config, and documentation file types
SUPPORTED_EXTENSIONS = [
    ".py", ".java", ".js", ".ts", ".go", ".c", ".cpp", ".h", ".hpp",
    ".cs", ".rb", ".php", ".swift", ".kt", ".scala",
    ".md", ".txt", ".rst", ".html", ".css", ".scss",
    ".yaml", ".yml", ".json", ".xml", ".proto", "Dockerfile", ".sh",
    ".tf", ".tfvars", ".bicep", ".gradle", "pom.xml", "requirements.txt",
    "package.json", "go.mod", "go.sum", "Cargo.toml"
]

# %% [markdown]
# ## Initialize API Clients
#
# Initializes the clients needed to interact with Google Cloud services using the specified PROJECT_ID and LOCATION.
#
# - vertexai.init: Initializes the Vertex AI SDK.
# - genai.Client: Creates a client for the Generative AI API (convenience wrapper).
# - storage.Client: Creates a client for Google Cloud Storage.

# %%
vertexai.init(project=PROJECT_ID, location=LOCATION)
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)
storage_client = storage.Client(project=PROJECT_ID)
# Out:
# e:\proyecto\ia-generativa-cartera\google\vertexai\.venv\Lib\site-packages\google\auth\_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %% [markdown]
# ## Data Preparation
# ### Clone GitHub Repository
#
# Clones the public Git repository specified by GITHUB_URL into a local directory (./cloned_repo). It uses the gitpython library. Error handling is included in case the cloning fails (e.g., repository not found, network issues, directory already exists).
#
# Note: The local path ./cloned_repo is hardcoded in the clone_from command in this cell.

# %%
try:
  git.Repo.clone_from(GITHUB_URL, LOCAL_REPO_PATH)
except git.GitCommandError as e:
  print(f"Error cloning repository: {e}")
# Out:
# Error cloning repository: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/google/adk-python ./cloned_repo
#   stderr: 'fatal: destination path './cloned_repo' already exists and is not an empty directory.
# '

# %% [markdown]
# ## Verify GCS Bucket Access
#
# Checks if the specified Google Cloud Storage bucket (BUCKET_NAME) exists and if the authenticated user or service account has permissions to access it. This helps catch configuration errors early.

# %%
try:
    bucket = storage_client.get_bucket(BUCKET_NAME)
    print(bucket.name)
except Exception as e:
    print(f"Error accessing GCS bucket '{BUCKET_NAME}': {e}")
# Out:
# rag-wlopezob

# %% [markdown]
# ## Upload Code Files to GCS
#
# This cell walks through the locally cloned repository (LOCAL_REPO_PATH, implicitly ./cloned_repo from the clone step) and uploads relevant files to the specified Google Cloud Storage bucket (BUCKET_NAME) and folder (GCS_FOLDER_PATH).
#
# Key actions:
#
# - Skips the .git directory.
# - Filters files based on SUPPORTED_EXTENSIONS (case-insensitive check).
# - Optionally skips files larger than MAX_FILE_SIZE_MB.
# - Preserves the relative directory structure within the specified GCS folder.
# - Uploads files as GCS objects (blobs).
# - Prints progress and a final summary.

# %%
uploaded_file_count = 0
skipped_file_count = 0

# Calculate max size in bytes once, if applicable
max_bytes = 0
if MAX_FILE_SIZE_MB > 0:
    max_bytes = MAX_FILE_SIZE_MB * 1024 * 1024
    print(f"Applying max file size limit: {MAX_FILE_SIZE_MB} MB ({max_bytes} bytes)")

for root, dirs, files in os.walk(LOCAL_REPO_PATH):
    # Skip '.git' directory explicitly to avoid uploading git metadata
    if any(folder in dirs for folder in ['.git', '.github']):
        dirs.remove('.git')
        dirs.remove('.github')

    for file in files:
        file_lower = file.lower() # Use lowercase for case-insensitive checks
        local_file_path = os.path.join(root, file)

        # Check if the file has a supported extension (case-insensitive)
        # or if the exact filename is in the list (e.g., "Dockerfile")
        is_supported = any(file_lower.endswith(ext.lower()) for ext in SUPPORTED_EXTENSIONS) or \
                       file in SUPPORTED_EXTENSIONS # Check exact match for non-extension files

        if is_supported:
            try:
                if max_bytes > 0: # Only check if a limit is set
                    file_size_bytes = os.path.getsize(local_file_path)
                    if file_size_bytes > max_bytes:
                        print(f"  Skipping large file ({(file_size_bytes / (1024*1024)):.2f} MB > {MAX_FILE_SIZE_MB} MB): {local_file_path}")
                        skipped_file_count += 1
                        continue # Skip to the next file

                # Create a relative path to maintain structure in GCS
                relative_path = os.path.relpath(local_file_path, LOCAL_REPO_PATH)

                # Construct the destination blob name within the specified GCS folder path
                if GCS_FOLDER_PATH:
                    gcs_blob_name = os.path.join(GCS_FOLDER_PATH, relative_path)
                else:
                    gcs_blob_name = relative_path
                gcs_blob_name = gcs_blob_name.replace("\\", "/")
                print(gcs_blob_name)

                # Get the blob object and upload the file
                blob = bucket.blob(gcs_blob_name)
                blob.upload_from_filename(local_file_path)
                uploaded_file_count += 1

                # Print progress periodically
                if uploaded_file_count % 100 == 0:
                    print(f"  Uploaded {uploaded_file_count} files (skipped: {skipped_file_count})...")

            except Exception as e:
                print(f"  Error uploading {local_file_path} to gs://{BUCKET_NAME}/{gcs_blob_name}: {e}")

# --- Final Report ---
print(f"\nFinished uploading.")
print(f"Total supported files uploaded: {uploaded_file_count}")
if skipped_file_count > 0:
    print(f"Total files skipped due to size limit: {skipped_file_count}")

if uploaded_file_count == 0:
    print(f"\nWarning: No supported files were found (within size limits) in '{LOCAL_REPO_PATH}' or uploaded to '{GCS_UPLOAD_URI}'.")
    print("The RAG Engine will have no data from this source.")
# Out:
# Applying max file size limit: 50 MB (52428800 bytes)
# adk-python/autoformat.sh
# adk-python/CHANGELOG.md
# adk-python/CONTRIBUTING.md
# adk-python/README.md
# adk-python/contributing/samples/application_integration_agent/agent.py
# adk-python/contributing/samples/application_integration_agent/README.md
# adk-python/contributing/samples/application_integration_agent/__init__.py
# adk-python/contributing/samples/artifact_save_text/agent.py
# adk-python/contributing/samples/artifact_save_text/__init__.py
# adk-python/contributing/samples/bigquery/agent.py
# adk-python/contributing/samples/bigquery/README.md
# adk-python/src/google/adk/flows/llm_flows/__init__.py
# adk-python/src/google/adk/memory/base_memory_service.py
# adk-python/src/google/adk/memory/in_memory_memory_service.py
# adk-python/src/google/adk/memory/memory_entry.py
# adk-python/src/google/adk/memory/vertex_ai_rag_memory_service.py
# adk-python/src/google/adk/memory/_utils.py
# adk-python/src/google/adk/memory/__init__.py
# adk-python/src/google/adk/models/anthropic_llm.py
# adk-python/src/google/adk/models/base_llm.py
# adk-python/src/google/adk/models/base_llm_connection.py
# adk-python/src/google/adk/models/gemini_llm_connection.py
# adk-python/src/google/adk/models/google_llm.py
# adk-python/src/google/adk/models/lite_llm.py
# adk-python/src/google/adk/models/llm_request.py
# adk-python/src/google/adk/models/llm_response.py
# adk-python/src/google/adk/models/registry.py
# adk-python/src/google/adk/models/__init__.py
# adk-python/src/google/adk/planners/base_planner.py
# adk-python/src/google/adk/planners/built_in_planner.py
#   Uploaded 200 files (skipped: 0)...
# adk-python/src/google/adk/planners/plan_re_act_planner.py
# adk-python/src/google/adk/planners/__init__.py
# adk-python/src/google/adk/sessions/base_session_service.py
# adk-python/src/google/adk/sessions/database_session_service.py
# adk-python/src/google/adk/sessions/in_memory_session_service.py
# adk-python/src/google/adk/sessions/session.py
# adk-python/src/google/adk/sessions/state.py
# adk-python/src/google/adk/sessions/vertex_ai_session_service.py
# adk-python/src/google/adk/sessions/_session_util.py
# adk-python/src/google/adk/sessions/__init__.py
# adk-python/src/google/adk/tools/agent_tool.py
# adk-python/src/google/adk/tools/base_tool.py
# adk-python/src/google/adk/tools/base_toolset.py
# adk-python/src/google/adk/tools/crewai_tool.py
# adk-python/src/google/adk/tools/enterprise_search_tool.py
# adk-python/src/google/adk/tools/example_tool.py
# adk-python/src/google/adk/tools/exit_loop_tool.py
# adk-python/src/google/adk/tools/function_tool.py
# adk-python/src/google/adk/tools/get_user_choice_tool.py
# adk-python/src/google/adk/tools/google_search_tool.py
# adk-python/src/google/adk/tools/langchain_tool.py
# adk-python/src/google/adk/tools/load_artifacts_tool.py
# adk-python/src/google/adk/tools/load_memory_tool.py
# adk-python/src/google/adk/tools/load_web_page.py
# adk-python/src/google/adk/tools/long_running_tool.py
# adk-python/src/google/adk/tools/preload_memory_tool.py
# adk-python/src/google/adk/tools/toolbox_toolset.py
# adk-python/src/google/adk/tools/tool_context.py
# adk-python/src/google/adk/tools/transfer_to_agent_tool.py
# adk-python/src/google/adk/tools/vertex_ai_search_tool.py
# adk-python/src/google/adk/tools/_automatic_function_calling_util.py
# adk-python/src/google/adk/tools/_function_parameter_parse_util.py
# adk-python/src/google/adk/tools/_memory_entry_utils.py
# adk-python/src/google/adk/tools/__init__.py
# adk-python/src/google/adk/tools/apihub_tool/apihub_toolset.py
# adk-python/src/google/adk/tools/apihub_tool/__init__.py
# adk-python/src/google/adk/tools/apihub_tool/clients/apihub_client.py
# adk-python/src/google/adk/tools/apihub_tool/clients/secret_client.py
# adk-python/src/google/adk/tools/apihub_tool/clients/__init__.py
# adk-python/src/google/adk/tools/application_integration_tool/application_integration_toolset.py
# adk-python/src/google/adk/tools/application_integration_tool/integration_connector_tool.py
# adk-python/src/google/adk/tools/application_integration_tool/__init__.py
# adk-python/src/google/adk/tools/application_integration_tool/clients/connections_client.py
# adk-python/src/google/adk/tools/application_integration_tool/clients/integration_client.py
# adk-python/src/google/adk/tools/bigquery/bigquery_credentials.py
# adk-python/src/google/adk/tools/bigquery/bigquery_tool.py
# adk-python/src/google/adk/tools/bigquery/bigquery_toolset.py
# adk-python/src/google/adk/tools/bigquery/client.py
# adk-python/src/google/adk/tools/bigquery/metadata_tool.py
# adk-python/src/google/adk/tools/bigquery/query_tool.py
# adk-python/src/google/adk/tools/bigquery/__init__.py
# adk-python/src/google/adk/tools/google_api_tool/googleapi_to_openapi_converter.py
# adk-python/src/google/adk/tools/google_api_tool/google_api_tool.py
# adk-python/src/google/adk/tools/google_api_tool/google_api_toolset.py
# adk-python/src/google/adk/tools/google_api_tool/google_api_toolsets.py
# adk-python/src/google/adk/tools/google_api_tool/__init__.py
# adk-python/src/google/adk/tools/mcp_tool/conversion_utils.py
# adk-python/src/google/adk/tools/mcp_tool/mcp_session_manager.py
# adk-python/src/google/adk/tools/mcp_tool/mcp_tool.py
# adk-python/src/google/adk/tools/mcp_tool/mcp_toolset.py
# adk-python/src/google/adk/tools/mcp_tool/__init__.py
# adk-python/src/google/adk/tools/openapi_tool/__init__.py
# adk-python/src/google/adk/tools/openapi_tool/auth/auth_helpers.py
# adk-python/src/google/adk/tools/openapi_tool/auth/__init__.py
# adk-python/src/google/adk/tools/openapi_tool/auth/credential_exchangers/auto_auth_credential_exchanger.py
# adk-python/src/google/adk/tools/openapi_tool/auth/credential_exchangers/base_credential_exchanger.py
# adk-python/src/google/adk/tools/openapi_tool/auth/credential_exchangers/oauth2_exchanger.py
# adk-python/src/google/adk/tools/openapi_tool/auth/credential_exchangers/service_account_exchanger.py
# adk-python/src/google/adk/tools/openapi_tool/auth/credential_exchangers/__init__.py
# adk-python/src/google/adk/tools/openapi_tool/common/common.py
# adk-python/src/google/adk/tools/openapi_tool/common/__init__.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/openapi_spec_parser.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/openapi_toolset.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/operation_parser.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/rest_api_tool.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/tool_auth_handler.py
# adk-python/src/google/adk/tools/openapi_tool/openapi_spec_parser/__init__.py
# adk-python/src/google/adk/tools/retrieval/base_retrieval_tool.py
# adk-python/src/google/adk/tools/retrieval/files_retrieval.py
# adk-python/src/google/adk/tools/retrieval/llama_index_retrieval.py
# adk-python/tests/unittests/tools/openapi_tool/openapi_spec_parser/test_openapi_toolset.py
# adk-python/tests/unittests/tools/openapi_tool/openapi_spec_parser/test_operation_parser.py
# adk-python/tests/unittests/tools/openapi_tool/openapi_spec_parser/test_rest_api_tool.py
# adk-python/tests/unittests/tools/openapi_tool/openapi_spec_parser/test_tool_auth_handler.py
# adk-python/tests/unittests/tools/retrieval/test_vertex_ai_rag_retrieval.py
# adk-python/tests/unittests/tools/retrieval/__init__.py
# adk-python/tests/unittests/utils/test_instructions_utils.py
# adk-python/tests/unittests/utils/__init__.py
#
# Finished uploading.
# Total supported files uploaded: 438

# %% [markdown]
# ## 4. RAG Corpus Creation
#
# Creates a [Vertex AI RAG Corpus](https://cloud.google.com/vertex-ai/generative-ai/docs/rag-engine/manage-your-rag-corpus). A RAG Corpus is a container for the documents (in this case, code files) that will be indexed for retrieval.
#
# - It's configured with a display name and description.
# - It specifies the EMBEDDING_MODEL to be used for generating vector embeddings of the file contents during the import process. The embeddings are stored in an underlying vector database managed by Vertex AI.

# %%
rag_corpus = rag.create_corpus(
    display_name=RAG_CORPUS_DISPLAY_NAME,
    description=f"Codebase files from {GITHUB_URL}",
    backend_config=rag.RagVectorDbConfig(
        rag_embedding_model_config=rag.RagEmbeddingModelConfig(
            vertex_prediction_endpoint=rag.VertexPredictionEndpoint(
                publisher_model=EMBEDDING_MODEL
            )
        )
    )
)
rag_corpus.display_name
# Out:
# 'rag-corpus-code-efdca7e1-f0b2-424c-938d-284e2d4e3e02'

# %% [markdown]
# ## 5. File Ingestion: Import Files into Corpus
#
# Starts the asynchronous process of importing files from the GCS location (GCS_IMPORT_URI) into the newly created rag_corpus.
#
# - rag.import_files: Initiates the import job.
# - Chunking: The TransformationConfig specifies how the files are processed before indexing. Here, ChunkingConfig defines that files are split into chunks of 500 tokens with an overlap of 100 tokens. Chunking is essential for RAG as it allows the model to retrieve smaller, more relevant pieces of information.
#
# This process can take some time depending on the number and size of files.

# %%
import_response = rag.import_files(
    corpus_name=rag_corpus.name,
    paths=[GCS_IMPORT_URI],
    transformation_config=rag.TransformationConfig(
        chunking_config=rag.ChunkingConfig(
            chunk_size=500,
            chunk_overlap=100
        )
    ),
    #llm_parser=rag.LlmParserConfig(
      #model_name="gemini-2.5-pro-preview-05-06",
      #max_parsing_requests_per_min=100,
    #),
    timeout=1800
)

# %% [markdown]
# ## 6. RAG Tool Setup: Create Retrieval Tool
#
# Creates a Tool object that the Gemini model can use to perform retrieval from the RAG Corpus.
#
# - Tool: A generic container for tools that generative models can use (e.g., function calling, retrieval).
# - Retrieval: Specifies a retrieval source.
# - VertexRagStore: Points the retrieval tool specifically to one or more Vertex AI RAG Corpora (rag_corpora=[rag_corpus.name]).
#     * similarity_top_k=10: Instructs the tool to retrieve the top 10 most relevant chunks based on semantic similarity.
#     * vector_distance_threshold=0.5: Sets a threshold for the vector distance; chunks with distances greater than this (less similar) might be filtered out. (Note: The interpretation might vary depending on the distance metric used by the embedding model).
#
# This tool configuration tells the Gemini model how to use the RAG Corpus when it needs external information to answer a query.

# %%
rag_retrieval_tool = Tool(
    retrieval=Retrieval(
        vertex_rag_store=VertexRagStore(
            rag_corpora=[rag_corpus.name],
            similarity_top_k=10,
            vector_distance_threshold=0.5,
        )
    )
)

rag_retrieval_tool
# Out:
# Tool(function_declarations=None, retrieval=Retrieval(disable_attribution=None, vertex_ai_search=None, vertex_rag_store=VertexRagStore(rag_corpora=['projects/1098081038399/locations/us-central1/ragCorpora/7991637538768945152'], rag_resources=None, rag_retrieval_config=None, similarity_top_k=10, vector_distance_threshold=0.5)), google_search=None, google_search_retrieval=None, enterprise_web_search=None, google_maps=None, url_context=None, code_execution=None)

# %% [markdown]
# ### Ask Questions about the Codebase
#
# Now, use the configured Gemini model (MODEL_ID) along with the rag_retrieval_tool to ask a question about the indexed codebase.
#
# - The GenerateContentConfig(tools=[rag_retrieval_tool]) tells the model it can use the RAG tool.
# - When you provide a prompt (like "What is the primary purpose..."), the model first attempts to retrieve relevant chunks from the RAG Corpus using the tool.
# - It then synthesizes an answer based on both its internal knowledge and the retrieved information from the codebase chunks.
# - The response text is displayed as Markdown.

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents="What is the primary purpose or main functionality of this codebase?, what'is the main functionality?",
    config=GenerateContentConfig(tools=[rag_retrieval_tool]),
)

display(Markdown(response.text))
# Out:
# The main functionality of this codebase, known as the Agent Development Kit (ADK), is to provide an open-source Python toolkit and a flexible, modular framework for building, evaluating, and deploying sophisticated AI agents. It is designed for developing and deploying AI agents, making it easier to create, deploy, and orchestrate agentic architectures.

# %% [markdown]
# ## 8. Test in Vertex AI Studio
#
# This cell generates a direct clickable link to the [Vertex AI Studio](https://console.cloud.google.com/vertex-ai/studio) in the Google Cloud Console. The link is specifically constructed to open the Multimodal Studio page with the RAG Corpus created in this notebook already selected. This allows you to interactively test the RAG setup by asking questions directly in the UI.
#
# - It URL-encodes the RAG Corpus resource name for use in the URL query parameters.
# - It uses IPython.display.HTML to render a clickable link in the notebook output.

# %%
# URL encode the '/' characters in the resource name by replacing them with '%2F'
encoded_rag_corpus_name = rag_corpus.name.replace("/", "%2F")

# Construct the full URL
vertex_ai_studio_url = (
    f"https://console.cloud.google.com/vertex-ai/studio/multimodal"
    f";ragCorpusName={encoded_rag_corpus_name}"
    f"?project={PROJECT_ID}"
)

# Create the HTML link
link_text = f"Probar el corpus RAG en Vertex AI Studio"
link_html = f'<a href="{vertex_ai_studio_url}" target="_blank">{link_text}</a>'

# Display the clickable link in Colab output
print("Click para probar el RAG Corpus en Vertex AI Studio:")
display(HTML(link_html))
# Out:
# Click para probar el RAG Corpus en Vertex AI Studio:
# <a href="https://console.cloud.google.com/vertex-ai/studio/multimodal;ragCorpusName=projects%2F1098081038399%2Flocations%2Fus-central1%2FragCorpora%2F7991637538768945152?project=masmovil-461118" target="_blank">Probar el corpus RAG en Vertex AI Studio</a>
